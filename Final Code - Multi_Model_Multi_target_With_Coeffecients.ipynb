# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import operator
import numpy as np
import pandas as pd
    

# paste your training and testing dataset name here
train_df=pd.read_csv("train.csv")
test_df=pd.read_csv("test.csv")

#paste inside l=[] names of all the column you want to be predicted and used for predictions, ie names of all the labels


def evaluate():
    n=[]
    imp=[]
    for name, importance in zip(X_train.columns, m):
        n.append(name)
        imp.append(importance)
    results= dict(zip(n, imp))
    sorted_results = sorted(results.items(), key=operator.itemgetter(1))
    print '******************************'
    print ''
    print 'Top 5 Important contributor to the features are : '
    print ''
    print sorted_results[-1]
    print sorted_results[-2]
    print sorted_results[-3]
    print sorted_results[-4]
    print sorted_results[-5]

    print '_______________________________________________________________________________________________'
    print '_______________________________________________________________________________________________'



l=['Support Level(IE?)','Assignment group','Priority','Hour Resolved','Weightage','Highest Assignment group','Automation Pickup Time (Min)','Technician Pickup Time (Min)']

for index in range (1,8):

    y=train_df[l[index]]
    X=train_df.drop(l[index], axis=1)

    print 'Now Predicting : '  + l[index]+'\n'

    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
    
    algo_name=['LinearRegression()','LogisticRegression()','LinearDiscriminantAnalysis()','KNeighborsClassifier()','DecisionTreeClassifier()','GaussianNB()','SVC()']
    
    algo=[LinearRegression(),LogisticRegression(),LinearDiscriminantAnalysis(),KNeighborsClassifier(),DecisionTreeClassifier(),GaussianNB(),SVC()]

    for item in range(0,7):

        model=algo[item]

        model.fit(X_train, y_train)

        print  '\n'+ algo_name[item]

        print model.score(X_test, y_test)

        y_pred=model.predict(X_test)
        
        df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
        
        print df.head()
        
        print '----------------------------------------------------------'
        
        #uncomment to save csv files of the results
        #name=l[index]+'.csv'

        #df.to_csv(name)
        
        
        
        
        m=[]
        
        if algo_name[item]=='LinearRegression()':
            m=model.coef_
            evaluate()

        elif algo_name[item]=='DecisionTreeClassifier()':
            m=model.feature_importances_
            evaluate()
        
        elif algo_name[item]=='KNeighborsClassifier()':
            print 'Coefficeints of variable in this algo provide no useful information'  
            

    print '_______________________________________________________________________________________________'
    print '_______________________________________________________________________________________________'
# Out:
# Now Predicting : Assignment group
#
#
# LinearRegression()
# 0.7676417420695734
#      Actual  Predicted
# 54        2   2.232233
# 124       5   4.860841
# 264       5   4.490647
# 175       5   4.849925
# 283       6   6.534727
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Highest Assignment group', 0.7889862035098156)
# ('IE Catgory', 0.43838693987425714)
# ('Initial Priority', 0.14374047665312803)
# ('Knowledge Article Used?', 0.11953025800495339)
# ('Week Resolved', 0.10912993250829373)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# LogisticRegression()
# 0.9358974358974359
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       6          6
# ----------------------------------------------------------
#
# LinearDiscriminantAnalysis()
# 0.9102564102564102
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       6          5
# ----------------------------------------------------------
#
# KNeighborsClassifier()
# 0.782051282051282
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       6          5
# ----------------------------------------------------------
# Coefficeints of variable in this algo provide no useful information
#
# DecisionTreeClassifier()
# 0.9743589743589743
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       6          4
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Highest Assignment group', 0.7603526476597028)
# ('Weightage', 0.19459229315333554)
# ('Cluster', 0.02782812479194684)
# ('Hour Resolved', 0.008613467197507354)
# ('Week Escala0d', 0.008613467197507354)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# GaussianNB()
# 0.9487179487179487
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       6          6
# ----------------------------------------------------------
#
# SVC()
# 0.7692307692307693
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       6          2
# ----------------------------------------------------------
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
# Now Predicting : Priority
#
#
# LinearRegression()
# 0.5055768400952267
#      Actual  Predicted
# 54        3   3.310600
# 124       1   1.156008
# 264       2   2.078118
# 175       2   2.113162
# 283       4   3.809793
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Initial Priority', 0.743330090544596)
# ('MTTR SLA Met?', 0.39935427149641833)
# ('05 min or less?', 0.2081585397425306)
# ('IE Catgory', 0.18679266860488522)
# ('Reopened?', 0.053345623279766136)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# LogisticRegression()
# 0.7307692307692307
#      Actual  Predicted
# 54        3          3
# 124       1          2
# 264       2          2
# 175       2          2
# 283       4          3
# ----------------------------------------------------------
#
# LinearDiscriminantAnalysis()
# 0.782051282051282
#      Actual  Predicted
# 54        3          3
# 124       1          2
# 264       2          2
# 175       2          2
# 283       4          3
# ----------------------------------------------------------
#
# KNeighborsClassifier()
# 0.5128205128205128
#      Actual  Predicted
# 54        3          3
# 124       1          2
# 264       2          3
# 175       2          2
# 283       4          2
# ----------------------------------------------------------
# Coefficeints of variable in this algo provide no useful information
#
# DecisionTreeClassifier()
# 0.9230769230769231
#      Actual  Predicted
# 54        3          3
# 124       1          1
# 264       2          2
# 175       2          2
# 283       4          4
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Initial Priority', 0.8103487518333039)
# ('IE Escalation Time (Hrs)', 0.08101130206666356)
# ('Assignment group', 0.05205461172854452)
# ('Week Resolved', 0.014202073053032956)
# ('Week Escala0d', 0.009011803603695995)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# GaussianNB()
# 0.5769230769230769
#      Actual  Predicted
# 54        3          2
# 124       1          2
# 264       2          2
# 175       2          2
# 283       4          3
# ----------------------------------------------------------
#
# SVC()
# 0.5897435897435898
#      Actual  Predicted
# 54        3          3
# 124       1          2
# 264       2          3
# 175       2          2
# 283       4          3
# ----------------------------------------------------------
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
# Now Predicting : Hour Resolved
#
#
# LinearRegression()
# -1.3880903548998988
#      Actual  Predicted
# 54       14  13.437656
# 124       6   6.701929
# 264       9   8.729806
# 175       6   6.683764
# 283      21  13.061433
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Automation Pickup in < 5 Min?', 2.523913325141288)
# ('05 min or less?', 1.998283074467832)
# ('Automation Pickup Time Range', 1.8416096998608509)
# ('Week Resolved', 1.1699721513466228)
# ('Priority', 1.0154115157251837)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# LogisticRegression()
# 0.38461538461538464
#      Actual  Predicted
# 54       14         12
# 124       6          6
# 264       9         11
# 175       6          6
# 283      21         13
# ----------------------------------------------------------
#
# LinearDiscriminantAnalysis()
# 0.4358974358974359
#      Actual  Predicted
# 54       14         12
# 124       6          6
# 264       9          9
# 175       6          6
# 283      21         11
# ----------------------------------------------------------
#
# KNeighborsClassifier()
# 0.3974358974358974
#      Actual  Predicted
# 54       14         16
# 124       6          6
# 264       9          9
# 175       6          6
# 283      21         11
# ----------------------------------------------------------
# Coefficeints of variable in this algo provide no useful information
#
# DecisionTreeClassifier()
# 0.5128205128205128
#      Actual  Predicted
# 54       14         12
# 124       6          6
# 264       9          9
# 175       6          6
# 283      21         11
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Week Resolved', 0.1415007134868707)
# ('Resolved < 60 Min?', 0.12387403745146106)
# ('Business Resolution Time (Hrs)', 0.12271018343227397)
# ('IE Escalation Time (Hrs)', 0.08622208615616996)
# ('Week Escala0d', 0.07389006103517226)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# GaussianNB()
# 0.34615384615384615
#      Actual  Predicted
# 54       14         18
# 124       6          6
# 264       9          9
# 175       6          6
# 283      21         13
# ----------------------------------------------------------
#
# SVC()
# 0.4358974358974359
#      Actual  Predicted
# 54       14         11
# 124       6          6
# 264       9          9
# 175       6          6
# 283      21         11
# ----------------------------------------------------------
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
# Now Predicting : Weightage
#
#
# LinearRegression()
# 0.9039584967514499
#      Actual  Predicted
# 54       30  31.065178
# 124      30  29.702247
# 264      30  29.563964
# 175      30  30.147976
# 283      10  13.254330
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Highest Assignment group', 0.8275929983904161)
# ('Week Escala0d', 0.699913389123358)
# ('Initial Priority', 0.6630710139115435)
# ('05 min or less?', 0.41634662556703866)
# ('Reopened?', 0.16326934888291622)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# LogisticRegression()
# 0.9230769230769231
#      Actual  Predicted
# 54       30         30
# 124      30         30
# 264      30         30
# 175      30         30
# 283      10         10
# ----------------------------------------------------------
#
# LinearDiscriminantAnalysis()
# 0.9230769230769231
#      Actual  Predicted
# 54       30         30
# 124      30         30
# 264      30         30
# 175      30         30
# 283      10         30
# ----------------------------------------------------------
#
# KNeighborsClassifier()
# 0.8974358974358975
#      Actual  Predicted
# 54       30         30
# 124      30         30
# 264      30         30
# 175      30         30
# 283      10         30
# ----------------------------------------------------------
# Coefficeints of variable in this algo provide no useful information
#
# DecisionTreeClassifier()
# 1.0
#      Actual  Predicted
# 54       30         30
# 124      30         30
# 264      30         30
# 175      30         30
# 283      10         10
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Support Level(IE?)', 0.580437305852043)
# ('Assignment group', 0.1649936842105263)
# ('Reassignment count', 0.13814227877385768)
# ('Automation Pickup Time (Min)', 0.031248803827751206)
# ('Initial Priority', 0.02806015037593985)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# GaussianNB()
# 0.9487179487179487
#      Actual  Predicted
# 54       30         20
# 124      30         30
# 264      30         30
# 175      30         30
# 283      10         10
# ----------------------------------------------------------
#
# SVC()
# 0.8846153846153846
#      Actual  Predicted
# 54       30         30
# 124      30         30
# 264      30         30
# 175      30         30
# 283      10         30
# ----------------------------------------------------------
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
# Now Predicting : Highest Assignment group
#
#
# LinearRegression()
# 0.8073846005642643
#      Actual  Predicted
# 54        2   2.016555
# 124       5   5.305990
# 264       5   4.831315
# 175       5   5.097702
# 283       5   3.152199
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Assignment group', 0.6264297060519465)
# ('Support Level(IE?)', 0.45860935623088056)
# ('MTTR SLA Met?', 0.4302402715732675)
# ('Resolved < 60 Min?', 0.22854539990006845)
# ('technician Pickup in < 15 Min?', 0.1845442063610909)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# LogisticRegression()
# 0.9743589743589743
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       5          2
# ----------------------------------------------------------
#
# LinearDiscriminantAnalysis()
# 0.9743589743589743
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       5          2
# ----------------------------------------------------------
#
# KNeighborsClassifier()
# 0.8846153846153846
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       5          5
# ----------------------------------------------------------
# Coefficeints of variable in this algo provide no useful information
#
# DecisionTreeClassifier()
# 1.0
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       5          5
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Assignment group', 0.7562642019029187)
# ('Business Resolution Time (Hrs)', 0.12820138235908096)
# ('Support Level(IE?)', 0.051176845204590315)
# ('Hour Resolved', 0.03729856601359073)
# ('Weightage', 0.02659085565269435)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# GaussianNB()
# 0.9358974358974359
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       5          2
# ----------------------------------------------------------
#
# SVC()
# 0.8589743589743589
#      Actual  Predicted
# 54        2          2
# 124       5          5
# 264       5          5
# 175       5          5
# 283       5          2
# ----------------------------------------------------------
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
# Now Predicting : Automation Pickup Time (Min)
#
#
# LinearRegression()
# 0.07253369592946768
#      Actual  Predicted
# 54        3 -10.190054
# 124       4 -34.309796
# 264       1 -84.982179
# 175       6  34.789728
# 283       6 -63.631123
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Automation Pickup Time Range', 872.3706680778141)
# ('Automation Pickup in < 5 Min?', 808.1235376870982)
# ('IE Catgory', 380.2136897782415)
# ('Reopened?', 187.3567163119452)
# ('Support Level(IE?)', 113.84270526349873)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# LogisticRegression()
# 0.3717948717948718
#      Actual  Predicted
# 54        3          4
# 124       4          4
# 264       1          1
# 175       6         10
# 283       6          1
# ----------------------------------------------------------
#
# LinearDiscriminantAnalysis()
# 0.34615384615384615
#      Actual  Predicted
# 54        3          4
# 124       4          4
# 264       1          1
# 175       6         10
# 283       6        940
# ----------------------------------------------------------
#
# KNeighborsClassifier()
# 0.2948717948717949
#      Actual  Predicted
# 54        3          1
# 124       4          3
# 264       1          1
# 175       6          2
# 283       6          2
# ----------------------------------------------------------
# Coefficeints of variable in this algo provide no useful information
#
# DecisionTreeClassifier()
# 0.41025641025641024
#      Actual  Predicted
# 54        3          4
# 124       4          3
# 264       1          1
# 175       6          8
# 283       6        556
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('IE Escalation Time (Hrs)', 0.21505078233809652)
# ('Business Resolution Time (Hrs)', 0.16793078145502435)
# ('Week Escala0d', 0.1350083651475635)
# ('Technician Pickup Time (Min)', 0.1221938143939605)
# ('Automation Pickup in < 5 Min?', 0.0830164805240202)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# GaussianNB()
# 0.4358974358974359
#      Actual  Predicted
# 54        3          4
# 124       4         11
# 264       1          1
# 175       6          8
# 283       6          5
# ----------------------------------------------------------
# SVC()
# 0.2948717948717949
#      Actual  Predicted
# 54        3          3
# 124       4          4
# 264       1          1
# 175       6         10
# 283       6          3
# ----------------------------------------------------------
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
# Now Predicting : Technician Pickup Time (Min)
#
#
# LinearRegression()
# 0.37967489681469124
#      Actual    Predicted
# 54      110  1199.146917
# 124      10 -2969.862992
# 264       6 -4093.232507
# 175      20   372.316799
# 283      81  3010.339816
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('Cluster', 6460.963542901064)
# ('MTTR SLA Met?', 2626.5710720016973)
# ('05 min or less?', 938.3004898790623)
# ('Reassign > 5?', 885.0885670006752)
# ('Reopen count', 580.4824589601927)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# LogisticRegression()
# 0.10256410256410256
#      Actual  Predicted
# 54      110         21
# 124      10          9
# 264       6          9
# 175      20         19
# 283      81        241
# ----------------------------------------------------------
#
# LinearDiscriminantAnalysis()
# 0.1282051282051282
#      Actual  Predicted
# 54      110         11
# 124      10         10
# 264       6          6
# 175      20         19
# 283      81        241
# ----------------------------------------------------------
#
# KNeighborsClassifier()
# 0.08974358974358974
#      Actual  Predicted
# 54      110         20
# 124      10          9
# 264       6          6
# 175      20         44
# 283      81          5
# ----------------------------------------------------------
# Coefficeints of variable in this algo provide no useful information
#
# DecisionTreeClassifier()
# 0.21794871794871795
#      Actual  Predicted
# 54      110         25
# 124      10         10
# 264       6          6
# 175      20         20
# 283      81         45
# ----------------------------------------------------------
# ******************************
#
# Top 5 Important contributor to the features are :
#
# ('IE Escalation Time (Hrs)', 0.23563199142553742)
# ('Business Resolution Time (Hrs)', 0.12295842985850454)
# ('Automation Pickup Time (Min)', 0.08980433134416677)
# ('Week Resolved', 0.07520445665205525)
# ('Week Escala0d', 0.07436492797589349)
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
#
# GaussianNB()
# 0.10256410256410256
#      Actual  Predicted
# 54      110         21
# 124      10          9
# 264       6         11
# 175      20         19
# 283      81         16
# ----------------------------------------------------------
#
# SVC()
# 0.08974358974358974
#      Actual  Predicted
# 54      110          3
# 124      10          9
# 264       6          9
# 175      20         44
# 283      81          3
# ----------------------------------------------------------
# _______________________________________________________________________________________________
# _______________________________________________________________________________________________
